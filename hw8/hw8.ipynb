# %% [markdown]
# # Импорты и переменные

# %%
! pip install ffmpeg-python
# Out:
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in c:\programdata\anaconda3\lib\site-packages (from ffmpeg-python) (0.18.3)
# Installing collected packages: ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0

# %%
! pip install pyaudio
# Out:
# Collecting pyaudio
#   Downloading PyAudio-0.2.13-cp310-cp310-win_amd64.whl (164 kB)
#      -------------------------------------- 164.1/164.1 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: pyaudio
# Successfully installed pyaudio-0.2.13

# %%
from pathlib import Path

# %matplotlib inline
import matplotlib.gridspec as gs
import matplotlib.pyplot as plt
import numpy as np
from scipy import interpolate, signal
import pyaudio

# %%
N = 13
k = 1
duration = 0.5
fs = 100_000

# %%
# from hw1
def tone(k: str, duration: float = 0.0075, fs: int = 100_000) -> np.ndarray:
    freqs = {
        "1": [697, 1209],
        "2": [697, 1336],
        "3": [697, 1477],
        "4": [770, 1209],
        "5": [770, 1336],
        "6": [770, 1477],
        "7": [852, 1209],
        "8": [852, 1336],
        "9": [852, 1477],
        "0": [941, 1336],
        "a": [697, 1633],
        "b": [770, 1633],
        "c": [852, 1633],
        "d": [941, 1633],
        "*": [941, 1209],
        "#": [941, 1477],
    }
    f = freqs[k]
    samples = np.mean(
        np.sin(np.outer(f, 2 * np.pi * np.arange(fs * duration) / fs)),
        axis=0)
    return samples

# %%
def downsample(x: np.array, q: int) -> np.array:
    '''
    Каждый q-тый элемент массива
    '''
    return x[::q]

# %%
def draw_plots(
        samples: list[list[float]],
        q: int,
        title: str = None,
        filename: str = None,
        labels: list[str] = ["Decimated FIR", "Decimated IIR", "Downsampled"],
        ) -> None:

    t0 = np.arange(0, len(samples[1]) + 1, 1/q)[:len(samples[0])]
    t = np.arange(len(samples[1]))

    fig, ax = plt.subplots(dpi=100)
    ax.set_xlabel("Number of samples")
    ax.set_ylabel("Magnitude")
    ax.set_title(title)

    ax.plot(t0, samples[0], alpha=0.3, label="Original")

    for sample, label in zip(samples[1:], labels):
        ax.scatter(t, sample, s=2, alpha=0.7, label=label)
    ax.legend()
    if filename is not None:
        fig.savefig(f"img/{filename}.png")
    fig.show()

# %%
def draw_spectrums(
        samples: list[float],
        q_: int,
        title: str = None,
        filename: str = None,
        ) -> None:

    fig, ax = plt.subplots(dpi=150)
    ax.set_xlabel("Frequncy, Hz")
    ax.set_ylabel("Magnitude")
    ax.set_title(title)

    for sample, q in zip(samples, q_):
        fs = 100_000 / q
        freqs = np.fft.fftfreq(len(sample), 1 / fs)
        ffts = np.abs(np.fft.fft(sample)) / len(sample)
        freqs, ffts = zip(*sorted(zip(freqs, ffts)))
        ax.plot(freqs, ffts, alpha=0.7, label=q)
    ax.legend(title="Factor")

    if filename is not None:
        fig.savefig(f"img/{filename}.png")

# %%
def play_tone(samples: np.ndarray, fs: int = 100_000) -> None:
    p = pyaudio.PyAudio()
    stream = p.open(format=pyaudio.paFloat32, channels=1, rate=fs, output=True)
    stream.write(samples.astype(np.float32).tobytes())
    stream.stop_stream()
    stream.close()

# %% [markdown]
# # Задание 1

# %%
s = tone(str(k))
q = 10

# Понижение дискретизацию сигнала после применения фильтра сглаживания.
decimated_fir = signal.decimate(s, q, ftype="fir")
decimated_iir = signal.decimate(s, q, ftype="iir")
downsampled = downsample(s, q)

draw_plots([s, decimated_fir, decimated_iir, downsampled], q, f"Factor = {q}")
# Out:
# C:\Users\Киря\AppData\Local\Temp\ipykernel_11604\3735372279.py:24: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
s = tone(str(k))
q = 20

decimated_fir = signal.decimate(s, q, ftype="fir")
decimated_iir = signal.decimate(s, q, ftype="iir")
downsampled = downsample(s, q)

draw_plots([s, decimated_fir, decimated_iir, downsampled], q, f"Factor = {q}")
# Out:
# C:\Users\Киря\AppData\Local\Temp\ipykernel_11604\3735372279.py:24: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
s = tone(str(k))
q = 40

decimated_fir = signal.decimate(s, q, ftype="fir")
decimated_iir = signal.decimate(s, q, ftype="iir")
downsampled = downsample(s, q)

draw_plots([s, decimated_fir, decimated_iir, downsampled], q, f"Factor = {q}")
# Out:
# C:\Users\Киря\AppData\Local\Temp\ipykernel_11604\3735372279.py:24: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
samples = []
q = []
for q_ in [10, 20, 40]:
    samples.append(downsample(s, q_))
    q.append(q_)
draw_spectrums(samples, q, "Spectrum for different decimation factors")

# %% [markdown]
# ### Звук

# %%
s = tone(str(k), 0.5)

# %%
play_tone(s)

# %%
# factor 10, downsample + interpolation
# появился шум
q = 10
downsampled = downsample(s, q)
interpolate_func = interpolate.UnivariateSpline(np.arange(0, len(s), q)[:len(downsampled)], downsampled, s=5)
downsampled_interpolated = interpolate_func(np.arange(0, len(s)))
# normalize bc it sounds better this way. idk the reason
downsampled_interpolated /= np.max(downsampled_interpolated)
play_tone(downsampled_interpolated)

# %%
# factor 10, just downsample
# как оригинал
play_tone(downsampled, fs // q)

# %%
# factor 20, downsample + interpolation
# чуть меньше шума, чем у factor 10, downsample + interpolation
q = 20
downsampled = downsample(s, q)
interpolate_func = interpolate.UnivariateSpline(np.arange(0, len(s), q)[:len(downsampled)], downsampled, s=5)
downsampled_interpolated = interpolate_func(np.arange(0, len(s)))
downsampled_interpolated /= np.max(downsampled_interpolated)
play_tone(downsampled_interpolated)

# %%
# factor 20, just downsample
# как оригинал 
play_tone(downsampled, fs // q)

# %%
# factor 40, downsample + interpolation
# шума нет, но качество хуже
q = 40
downsampled = downsample(s, q)
interpolate_func = interpolate.UnivariateSpline(np.arange(0, len(s), q)[:len(downsampled)], downsampled, s=5)
downsampled_interpolated = interpolate_func(np.arange(0, len(s)))
play_tone(downsampled_interpolated)

# %%
# factor 40, just downsample
# как оригинал, только тише
play_tone(downsampled, fs // q)

# %% [markdown]
# # Задание 2

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython import display

plt.rcParams['animation.ffmpeg_path'] = "ffmpeg.exe"

s = tone(str(k))
t = np.arange(0, len(s))

fig, ax = plt.subplots(dpi=120)
ax.plot(t, s, alpha=0.3)
sct = ax.scatter([], [], s=2, c="r", label=" ")
l = ax.legend(title="Factor")

def frame(q: int):
    ss = downsample(s, q)
    tss = np.arange(0, len(s), q)
    sct.set_offsets(np.array([tss, ss]).T)
    l.get_texts()[0].set_text(q)
    return sct

anim = FuncAnimation(fig, frame, range(1, 50), interval=1_000)

video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <img src="data:image/png;base64,..." width="768">
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[34], line 25
#      21     return sct
#      23 anim = FuncAnimation(fig, frame, range(1, 50), interval=1_000)
# ---> 25 video = anim.to_html5_video()
#      26 html = display.HTML(video)
#      27 display.display(html)
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\animation.py:1276, in Animation.to_html5_video(self, embed_limit)
#    1273 path = Path(tmpdir, "temp.m4v")
#    1274 # We create a writer manually so that we can get the
#    1275 # appropriate size for the tag
# -> 1276 Writer = writers[mpl.rcParams['animation.writer']]
#    1277 writer = Writer(codec='h264',
#    1278                 bitrate=mpl.rcParams['animation.bitrate'],
#    1279                 fps=1000. / self._interval)
#    1280 self.save(str(path), writer=writer)
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\animation.py:148, in MovieWriterRegistry.__getitem__(self, name)
#     146 if self.is_available(name):
#     147     return self._registered[name]
# --> 148 raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %% [markdown]
# # Задание 3

# %%
# 
s = tone(str(k), 0.5)
t = np.arange(0, len(s))

fs = 100_000
freqs = np.fft.fftfreq(len(s), 1 / fs)
ffts = np.abs(np.fft.fft(s)) / len(s)
freqs, ffts = zip(*sorted(zip(freqs, ffts)))

fig, ax = plt.subplots(dpi=100)
ax.set_xlim(-5000, 5000)
ax.plot(freqs, ffts, alpha=0.2, label="Original")
lines = []
lines.append(ax.plot([], c="r", alpha=0.2, label=" ")[0])
lines.append(ax.plot([], c="g", alpha=0.2, label=" ")[0])

l = ax.legend(title="Factor")

def frame(q: int):
    fs = 100_000 / q

    downsampled = downsample(s, q)
    freqs = np.fft.fftfreq(len(downsampled), 1 / fs)
    ffts = np.abs(np.fft.fft(downsampled)) / len(downsampled)
    freqs, ffts = zip(*sorted(zip(freqs, ffts)))
    lines[0].set_data([freqs, ffts])
    l.get_texts()[1].set_text(f"Downsampled, {q}")

    decimated = signal.decimate(s, q, ftype="iir")
    freqs = np.fft.fftfreq(len(decimated), 1 / fs)
    ffts = np.abs(np.fft.fft(decimated)) / len(decimated)
    freqs, ffts = zip(*sorted(zip(freqs, ffts)))
    lines[1].set_data([freqs, ffts])
    l.get_texts()[2].set_text(f"Decimated, {q}")

    return sct

anim = FuncAnimation(fig, frame, range(1, 50), interval=1_000)

video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <img src="data:image/png;base64,..." width="672">
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[36], line 39
#      35     return sct
#      37 anim = FuncAnimation(fig, frame, range(1, 50), interval=1_000)
# ---> 39 video = anim.to_html5_video()
#      40 html = display.HTML(video)
#      41 display.display(html)
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\animation.py:1276, in Animation.to_html5_video(self, embed_limit)
#    1273 path = Path(tmpdir, "temp.m4v")
#    1274 # We create a writer manually so that we can get the
#    1275 # appropriate size for the tag
# -> 1276 Writer = writers[mpl.rcParams['animation.writer']]
#    1277 writer = Writer(codec='h264',
#    1278                 bitrate=mpl.rcParams['animation.bitrate'],
#    1279                 fps=1000. / self._interval)
#    1280 self.save(str(path), writer=writer)
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\animation.py:148, in MovieWriterRegistry.__getitem__(self, name)
#     146 if self.is_available(name):
#     147     return self._registered[name]
# --> 148 raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %% [markdown]
# # Задание 4

# %%
fs = 100_000

fig, ax = plt.subplots(dpi=100)
s = tone(str(k))
t = np.arange(0, len(s))
ax.plot(t, s, alpha=0.5, label="Original")
lines = []
lines.append(ax.plot([], "-o", lw=0.5, c="g", alpha=0.3, markersize=1, label=" ")[0])
lines.append(ax.plot([], "-o", lw=0.5, c="r", alpha=0.3, markersize=1, label=" ")[0])

l = ax.legend(title="Factor")

def frame(q: int):
    fs = 100_000 / q

    downsampled = downsample(s, q)
    interpolate_func = interpolate.UnivariateSpline(np.arange(0, len(s), q)[:len(downsampled)], downsampled, s=1)
    downsampled_interpolated = interpolate_func(np.arange(0, len(s)))
    t = np.arange(len(s))
    lines[0].set_data([t, downsampled_interpolated])
    l.get_texts()[1].set_text(f"Downsampled, {q}")

    decimated = signal.decimate(s, q, ftype="iir")
    interpolate_func = interpolate.UnivariateSpline(np.arange(0, len(s), q)[:len(decimated)], decimated, s=1)
    decimated_interpolated = interpolate_func(np.arange(0, len(s)))
    t = np.arange(len(s))
    lines[1].set_data([t, decimated_interpolated])
    l.get_texts()[2].set_text(f"Decimated, {q}")

    return sct

anim = FuncAnimation(fig, frame, range(1, 50), interval=1_000)

video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[37], line 34
#      30     return sct
#      32 anim = FuncAnimation(fig, frame, range(1, 50), interval=1_000)
# ---> 34 video = anim.to_html5_video()
#      35 html = display.HTML(video)
#      36 display.display(html)
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\animation.py:1276, in Animation.to_html5_video(self, embed_limit)
#    1273 path = Path(tmpdir, "temp.m4v")
#    1274 # We create a writer manually so that we can get the
#    1275 # appropriate size for the tag
# -> 1276 Writer = writers[mpl.rcParams['animation.writer']]
#    1277 writer = Writer(codec='h264',
#    1278                 bitrate=mpl.rcParams['animation.bitrate'],
#    1279                 fps=1000. / self._interval)
#    1280 self.save(str(path), writer=writer)
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\animation.py:148, in MovieWriterRegistry.__getitem__(self, name)
#     146 if self.is_available(name):
#     147     return self._registered[name]
# --> 148 raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available
